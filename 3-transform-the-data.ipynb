# %%
import pandas as pd
import numpy as np
from decimal import Decimal

# %%
# Retrieve the cleaned data frame from 2
df = pd.read_csv('fortune_2000_in_2021_cleaned.csv')
df
# Out:
#       Rank                                      Name        Country     Sales  \
# 0        1                                      ICBC          China  $190.5 B
# 1        2                            JPMorgan Chase  United States  $136.2 B
# 2        3                        Berkshire Hathaway  United States  $245.5 B
# 3        4                   China Construction Bank          China  $173.5 B
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $229.7 B
# ...    ...                                       ...            ...       ...
# 1995  1996                                     JTEKT          Japan   $13.1 B
# 1996  1997                 Insurance Australia Group      Australia    $5.4 B
# 1997  1997                         Sumec Corporation          China     $13 B
# 1998  1999                               Gold Fields   South Africa    $3.9 B
# 1999  1999                                    Paycom  United States    $841 M
#
#         Profit      Assets Market Value
# 0      $45.8 B  $4,914.7 B     $249.5 B
# 1      $40.4 B  $3,689.3 B     $464.8 B
# 2      $42.5 B    $873.7 B     $624.4 B
# 3      $39.3 B  $4,301.7 B     $210.4 B
# 4      $49.3 B    $510.3 B   $1,897.2 B
# ...        ...         ...          ...
# 1995  $-34.9 M       $12 B       $3.5 B
# 1996   $-212 M       $25 B       $9.3 B
# 1997   $79.2 M      $7.1 B       $1.3 B
# 1998  $718.1 M      $7.5 B       $8.9 B
# 1999  $143.4 M      $2.6 B        $24 B
#
# [2000 rows x 7 columns]

# %% [markdown]
# # Create function to convert numerical string to number
# ### The function takes a string in millions or billions and converts it to a number in millions

# %%
# Takes a string, removes dollar sign, converts to a float and into millions
def return_total_in_millions(total):
    # split string to a list
    total_as_list = total.split(" ")
    
    # remove dollar sign or any commas from total and convert to Decimal
    total_without_dollar_sign = total_as_list[0].replace('$','')
    total_without_dollar_sign = Decimal(total_without_dollar_sign.replace(',',''))
    
    # get 'M' or 'B' from list
    m_or_b = total_as_list[1]
    
    # If B - multiple by 1000
    if m_or_b == 'B':
        return total_without_dollar_sign * 1000
    else:
        return total_without_dollar_sign

# %%
# Quick function test
return_total_in_millions('$4,914.7 B')
# Out:
# Decimal('4914700.0')

# %% [markdown]
# - Here we'll create a test dataframe and test creating a new column based on an existing column with the 'return_total_in_millions' function.

# %%
df_test = pd.DataFrame(
    {
        "Total":["$26.2 B","$32.5 M","-$92.4 B","-182 M"]
    }
)

# %%
df_test
# Out:
#       Total
# 0   $26.2 B
# 1   $32.5 M
# 2  -$92.4 B
# 3    -182 M

# %%
df_test['Total (in millions)'] = df_test['Total'].apply(return_total_in_millions)

# %%
df_test
# Out:
#       Total Total (in millions)
# 0   $26.2 B             26200.0
# 1   $32.5 M                32.5
# 2  -$92.4 B            -92400.0
# 3    -182 M                -182

# %% [markdown]
# # Create new columns -  Profit, Assets and Market Value
# - Create a new (in millions) column from the existing columns:
# - Sales, Profit,Assets,Market Value

# %%
df['Sales (in millions)'] = df['Sales'].apply(return_total_in_millions)

# %%
df['Profit (in millions)'] = df['Profit'].apply(return_total_in_millions)

# %%
df['Assets (in millions)'] = df['Assets'].apply(return_total_in_millions)

# %%
df['Market Value (in millions)'] = df['Market Value'].apply(return_total_in_millions)

# %%
df
# Out:
#       Rank                                      Name        Country     Sales  \
# 0        1                                      ICBC          China  $190.5 B
# 1        2                            JPMorgan Chase  United States  $136.2 B
# 2        3                        Berkshire Hathaway  United States  $245.5 B
# 3        4                   China Construction Bank          China  $173.5 B
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $229.7 B
# ...    ...                                       ...            ...       ...
# 1995  1996                                     JTEKT          Japan   $13.1 B
# 1996  1997                 Insurance Australia Group      Australia    $5.4 B
# 1997  1997                         Sumec Corporation          China     $13 B
# 1998  1999                               Gold Fields   South Africa    $3.9 B
# 1999  1999                                    Paycom  United States    $841 M
#
#         Profit      Assets Market Value Sales (in millions)  \
# 0      $45.8 B  $4,914.7 B     $249.5 B            190500.0
# 1      $40.4 B  $3,689.3 B     $464.8 B            136200.0
# 2      $42.5 B    $873.7 B     $624.4 B            245500.0
# 3      $39.3 B  $4,301.7 B     $210.4 B            173500.0
# 4      $49.3 B    $510.3 B   $1,897.2 B            229700.0
# ...        ...         ...          ...                 ...
# 1995  $-34.9 M       $12 B       $3.5 B             13100.0
# 1996   $-212 M       $25 B       $9.3 B              5400.0
# 1997   $79.2 M      $7.1 B       $1.3 B               13000
# 1998  $718.1 M      $7.5 B       $8.9 B              3900.0
# 1999  $143.4 M      $2.6 B        $24 B                 841
#
#      Profit (in millions) Assets (in millions) Market Value (in millions)
# 0                 45800.0            4914700.0                   249500.0
# 1                 40400.0            3689300.0                   464800.0
# 2                 42500.0             873700.0                   624400.0
# 3                 39300.0            4301700.0                   210400.0
# 4                 49300.0             510300.0                  1897200.0
# ...                   ...                  ...                        ...
# 1995                -34.9                12000                     3500.0
# 1996                 -212                25000                     9300.0
# 1997                 79.2               7100.0                     1300.0
# 1998                718.1               7500.0                     8900.0
# 1999                143.4               2600.0                      24000
#
# [2000 rows x 11 columns]

# %% [markdown]
# # Randomly test rows from the data frame

# %%
# Get a random list of rows and compare 'Sales' to 'Sales (in millions)'
rand_nums = np.random.randint(0,1999, size=10)
pd.DataFrame(df.loc[rand_nums])
# Out:
#       Rank                           Name         Country    Sales    Profit  \
# 1054  1054                         Leidos   United States  $12.3 B    $628 M
# 727    728          Samsung Fire & Marine     South Korea    $18 B  $639.9 M
# 1770  1770                      Sartorius         Germany   $2.7 B  $258.5 M
# 1423  1424              SinoPac Financial          Taiwan   $1.8 B  $415.7 M
# 1821  1822              JD Sports Fashion  United Kingdom   $7.9 B  $288.5 M
# 1175  1176                      Schroders   United States   $3.3 B  $610.8 M
# 1534  1535  Jointown Pharmaceutical Group           China  $15.2 B  $406.6 M
# 261    262                          Tesla   United States  $31.5 B    $690 M
# 157    158                        L'Oréal          France  $31.9 B    $4.1 B
# 1822  1823                            A2A           Italy   $7.6 B    $415 M
#
#        Assets Market Value Sales (in millions) Profit (in millions)  \
# 1054  $12.5 B      $14.4 B             12300.0                  628
# 727   $84.4 B       $7.3 B               18000                639.9
# 1770   $5.8 B      $38.5 B              2700.0                258.5
# 1423  $76.3 B       $5.2 B              1800.0                415.7
# 1821   $7.1 B      $13.3 B              7900.0                288.5
# 1175  $29.6 B      $13.7 B              3300.0                610.8
# 1534  $11.6 B         $5 B             15200.0                406.6
# 261   $52.1 B     $710.1 B             31500.0                  690
# 157   $53.4 B     $225.7 B             31900.0               4100.0
# 1822    $15 B       $5.8 B              7600.0                  415
#
#      Assets (in millions) Market Value (in millions)
# 1054              12500.0                    14400.0
# 727               84400.0                     7300.0
# 1770               5800.0                    38500.0
# 1423              76300.0                     5200.0
# 1821               7100.0                    13300.0
# 1175              29600.0                    13700.0
# 1534              11600.0                       5000
# 261               52100.0                   710100.0
# 157               53400.0                   225700.0
# 1822                15000                     5800.0

# %% [markdown]
# # Save the dataframe

# %%
df.to_csv('fortune_2000_in_2021_cleaned_transformed.csv', index=False)
