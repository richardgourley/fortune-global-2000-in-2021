# %%
import pandas as pd

# %%
df = pd.read_csv('fortune_2000_in_2021.csv')

# %%
df
# Out:
#       Rank                                      Name        Country     Sales  \
# 0        1                                      ICBC          China  $190.5 B
# 1        2                            JPMorgan Chase  United States  $136.2 B
# 2        3                        Berkshire Hathaway  United States  $245.5 B
# 3        4                   China Construction Bank          China  $173.5 B
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $229.7 B
# ...    ...                                       ...            ...       ...
# 1995  1996                                     JTEKT          Japan   $13.1 B
# 1996  1997                 Insurance Australia Group      Australia    $5.4 B
# 1997  1997                         Sumec Corporation          China     $13 B
# 1998  1999                               Gold Fields   South Africa    $3.9 B
# 1999  1999                                    Paycom  United States    $841 M
#
# ...

# %% [markdown]
# # Business Questions

# %% [markdown]
# ### - The dataset is a list of the fortune 2000 companies globally with results from 2021.
# The questions below focus on 3 areas of interest
# - Countries - which countries appear most in the list for various metrics.
# - Profit and profit to sales comparison
# - Assets - which companies have the most assets (and which country they are in.)
#
# **BY COUNTRY**
#
# 1. Which countries have the highest number of companies in the list?
# 2. What share of companies on the list do the big two (USA and China) have in comparison to the rest of the world?
# 3. Which countries have the highest number of companies in the list that turned a profit in 2021?
# 4. Which countries have the fewest number of companies in the list that turned a profit in 2021?
#
# **BY PROFIT TO SALES**
#
# 5. Which of the 10 companies with the highest profit have the best profit to sales ratio?
#
# **BY ASSETS**
#
# 6. What are the top 20 companies in terms of assets?
